# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exploramos las características de los datos:

# %%
#traemos el ultimo DF guardado

df = pd.read_csv('C:/Users/User/Proyecto Coder/data/processed/df_merged.csv')
df.drop('Unnamed: 0', axis=1 ,inplace=True)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  Edad  \
# 0     7590-VHVEG  Female              0     Yes         No    27
# 1     5575-GNVDE    Male              0      No         No    57
# 2     3668-QPYBK    Male              0      No         No    18
# 3     7795-CFOCW    Male              0      No         No    18
# 4     9237-HQITU  Female              0      No         No    24
# ...          ...     ...            ...     ...        ...   ...
# 7038  6840-RESVB    Male              0     Yes        Yes    18
# 7039  2234-XADUH  Female              0     Yes        Yes    43
# 7040  4801-JZAZL  Female              0     Yes        Yes    25
# 7041  8361-LTMKD    Male              1     Yes         No    18
# 7042  3186-AJIEK    Male              0      No         No    18
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# ...

# %% [markdown]
# ## Visualizamos la info de las variables:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   Edad              7043 non-null   int64
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  PhoneService      7043 non-null   object
# ...

# %% [markdown]
# ## Verificamos valores faltantes:

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents   Edad  \
# 0          False   False          False    False       False  False
# 1          False   False          False    False       False  False
# 2          False   False          False    False       False  False
# 3          False   False          False    False       False  False
# 4          False   False          False    False       False  False
# ...          ...     ...            ...      ...         ...    ...
# 7038       False   False          False    False       False  False
# 7039       False   False          False    False       False  False
# 7040       False   False          False    False       False  False
# 7041       False   False          False    False       False  False
# 7042       False   False          False    False       False  False
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  ...  \
# 0             False            False           False         False  ...
# ...

# %% [markdown]
# ## Duplicados:

# %%
# A nivel general:
df.duplicated().sum()
# Out:
# 0

# %%
#a nivel de identificadores:
df.customerID.nunique()
# Out:
# 7043

# %%
# Mostramos informacion de las variables categoricas:
for column in df.columns:
    if df[column].dtype == 'object':
        unique_value = df[column].unique()
        print(f'Columna:{column}')
        print(f'categorias:{unique_value}\n')
# Out:
# Columna:customerID
# categorias:['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# Columna:gender
# categorias:['Female' 'Male']
#
# Columna:Partner
# categorias:['Yes' 'No']
#
# Columna:Dependents
# categorias:['No' 'Yes']
#
# Columna:MultipleLines
# categorias:['No phone service' 'No' 'Yes']
#
# Columna:InternetService
# categorias:['DSL' 'Fiber optic' 'No']
#
# Columna:OnlineSecurity
# categorias:['No' 'Yes' 'No internet service']
#
# Columna:OnlineBackup
# categorias:['Yes' 'No' 'No internet service']
#
# Columna:DeviceProtection
# categorias:['No' 'Yes' 'No internet service']
#
# Columna:TechSupport
# categorias:['No' 'Yes' 'No internet service']
#
# Columna:StreamingTV
# categorias:['No' 'Yes' 'No internet service']
#
# Columna:StreamingMovies
# categorias:['No' 'Yes' 'No internet service']
#
# Columna:PhoneService
# categorias:['No' 'Yes']
#
# Columna:Contract
# categorias:['Month-to-month' 'One year' 'Two year']
#
# ...

# %% [markdown]
# ### NO se Observan variables con categorias únicas,faltaria analizar despues la distribucion e importancia de cada una.

# %% [markdown]
# #### Existe una variable de tipo int que se comporta como categoria veamos las opciones:

# %%
jubilado = df['SeniorCitizen'].unique()
print(jubilado)
# Out:
# [0 1]

# %% [markdown]
# ### Tiene dos categorias analizaremos despes la distribución

# %%
df.to_csv('C:/Users/User/Proyecto Coder/data/processed/df_processed.csv')
