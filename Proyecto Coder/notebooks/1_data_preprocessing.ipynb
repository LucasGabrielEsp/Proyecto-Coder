# %% [markdown]
# ## ¿Cómo mejorar la retencion de clientes?:
# ### Este proyecto tiene como objetivo desarrollar un modelo predictivo que permita identificar a los clientes con alta probabilidad de abandonar nuestra empresa (churn) y así implementar estrategias de retención efectivas.
# ####

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Preguntas de interes:
#    * ¿Cuál es la distribución de las variables numéricas?
#    * ¿Existen diferencias significativas entre los clientes que se quedan y los que se van?
#    * ¿Hay variables altamente correlacionadas?
#    * ¿Existen patrones temporales en el churn?
#    * ¿Hay algún segmento de clientes particularmente propenso al churn?
#    * Contamos con 3 tablas que asignaremos a los DF llamados customer, perfil e internet. Estas continen informacion de clientes de la empresa de servicios de internet.

# %%
ruta = "C:/Users/User/Proyecto Coder/data/raw/"

# %%
customer = pd.read_csv(f'{ruta}customer_data.csv')

# %% [markdown]
# Como mi data set tiene demasiados atributos cualitativos agregaré una columna de edad que siga
# la distribucion Normal entre 18 y 80 años

# %%
# Definimos los parámetros de la distribución normal
media_edad = 32  # es la edad promedio de argentina
desviacion_estandar = 15  # Ajusta la desviación estándar

# Generamos una serie de edades aleatorias siguiendo una distribución normal
edades_aleatorias = np.random.normal(loc=media_edad, scale=desviacion_estandar, size=len(df)).round(0).astype(int)

# Aseguramos que las edades estén dentro del rango de 18 a 80 años
edades_aleatorias = np.clip(edades_aleatorias, 18, 80)

# Convertimos la serie de edades a un DataFrame y la agregamos al DataFrame original
customer_edades = pd.DataFrame({'Edad': edades_aleatorias})
customer = pd.concat([customer, customer_edades], axis=1)

print(customer.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  Edad
# 0  7590-VHVEG  Female              0     Yes         No    18
# 1  5575-GNVDE    Male              0      No         No    18
# 2  3668-QPYBK    Male              0      No         No    51
# 3  7795-CFOCW    Male              0      No         No    18
# 4  9237-HQITU  Female              0      No         No    36

# %%
perfil= pd.read_csv(f'{ruta}churn_data.csv')
perfil
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# ...          ...     ...          ...             ...              ...
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# ...

# %%
internet= pd.read_csv(f'{ruta}internet_data.csv')

# %% [markdown]
# ### Joineamos las tablas y verificamos que esten todos los atributos y la nueva columna edad:

# %%
df = pd.merge(customer, internet, on ="customerID", how = "left")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents     MultipleLines  \
# 0     7590-VHVEG  Female              0     Yes         No  No phone service
# 1     5575-GNVDE    Male              0      No         No                No
# 2     3668-QPYBK    Male              0      No         No                No
# 3     7795-CFOCW    Male              0      No         No  No phone service
# 4     9237-HQITU  Female              0      No         No                No
# ...          ...     ...            ...     ...        ...               ...
# 7038  6840-RESVB    Male              0     Yes        Yes               Yes
# 7039  2234-XADUH  Female              0     Yes        Yes               Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes  No phone service
# 7041  8361-LTMKD    Male              1     Yes         No               Yes
# 7042  3186-AJIEK    Male              0      No         No                No
#
# ...

# %%
df = pd.merge(df, perfil, on ="customerID", how = "left")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  Edad  \
# 0     7590-VHVEG  Female              0     Yes         No    27
# 1     5575-GNVDE    Male              0      No         No    57
# 2     3668-QPYBK    Male              0      No         No    18
# 3     7795-CFOCW    Male              0      No         No    18
# 4     9237-HQITU  Female              0      No         No    24
# ...          ...     ...            ...     ...        ...   ...
# 7038  6840-RESVB    Male              0     Yes        Yes    18
# 7039  2234-XADUH  Female              0     Yes        Yes    43
# 7040  4801-JZAZL  Female              0     Yes        Yes    25
# 7041  8361-LTMKD    Male              1     Yes         No    18
# 7042  3186-AJIEK    Male              0      No         No    18
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# ...

# %% [markdown]
# Guardamos el DF en un archivo .csv dentro de la carpeta data/processed

# %%
df.to_csv('C:/Users/User/Proyecto Coder/data/processed/df_merged.csv')
